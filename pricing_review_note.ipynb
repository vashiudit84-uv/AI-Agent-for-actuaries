# %% [markdown]
# # PRICING REVIEW NOTE
#
# **Cedant / Program:** Example Mutual Insurance Co.
# **Layer:** 50,000,000 xs 50,000,000 (1 reinstatement(s))
# **Renewal period incepting:** 2027
# **Prepared by:** Treaty Pricing Submission Analyst Agent (draft — pending peer review)
#
# ------------------------------------------------------------------------
#
# ## SECTION A: TECHNICAL PRICE INDICATION (Actuarial)
#
# ### 1. Submission Validation
#
# Status: **PASS_WITH_FLAGS**
# Years of history supplied: 11
# Data limitation flag: False
# Issues identified:
#
# - Missing premium for year 2027.
#
# ### 2. Trend & On-Level
#
# - Peril basis: wind
# - Approved loss trend applied: 6.00% per annum (per Approved Trend Assumptions doc)
# - TIV/on-level trend applied: 4.00% per annum
#
# ### 3. Treaty Structure Applied to Losses
#
# - Attachment: 50,000,000
# - Limit: 50,000,000
# - Reinstatements: 1
# - Annual aggregate limit to layer: 100,000,000
#
# ### 4. Burning Cost
#
# - Years used: \[2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026\]
# - Premium-weighted average burning cost ratio: 157.65%
# - Simple average burning cost ratio: 157.12%
# - Year-to-year volatility (std dev of annual ratio): 241.92%
# - Experience indication (current premium basis): 13,198,605
#
# ### 5. Frequency / Severity (Exposure) Model
#
# - Claims to layer in experience period: 3 over 10 years
# - Fitted annual frequency (Poisson λ): 0.3
# - Fitted severity to layer (lognormal μ, σ): 17.6296, 0.1546
# - Modeled expected annual loss to layer: 13,764,080
# - Exposure indication loss cost ratio: 164.40%
#
# ### 6. Credibility
#
# - Claims to layer: 3
# - Full credibility standard: 15 claims
# - Credibility weight Z applied to experience indication: 0.4472
# - Basis: Standard partial credibility formula applied.
#
# ### 7. Technical Price Build-Up
#
# - Blended expected annual loss cost: 13,511,199
# - Expense load: 10.00% \| Internal admin: 1.50%
# - Capital load (proxy, % of loss cost): 12.00% = 1,621,344
# - Target technical margin: 6.00%
# - **Technical Price Indication: 18,342,477**
#   (219.09% of current on-level subject premium)
#
# ### 8. Sensitivities
#
# | Scenario               | Technical Premium | % vs Base |
# |------------------------|------------------:|----------:|
# | base_case              |        18,342,477 |    +0.00% |
# | attachment_minus_25pct |        19,989,714 |    +8.98% |
# | attachment_plus_25pct  |        15,490,700 |   -15.55% |
# | limit_minus_25pct      |        14,992,413 |   -18.26% |
# | limit_plus_25pct       |        20,488,001 |   +11.70% |
# | trend_minus_200bps     |        18,108,770 |    -1.27% |
# | trend_plus_200bps      |        18,576,184 |    +1.27% |
# | largest_loss_removed   |        11,775,662 |   -35.80% |
#
# ### 9. Comparison to Expiring
#
# - Expiring technical premium: 7,800,000
# - Indicated technical rate change vs expiring: +135.16%
#
# *This technical price indication is an actuarial reference point derived strictly
# from the governed methodology, approved assumptions, and the tool trace below.
# It is not a quote, bind instruction, or commercial recommendation.*
#
# ------------------------------------------------------------------------
#
# ## SECTION B: COMMERCIAL DECISION (Underwriting — Not Completed by Agent)
#
# - Final commercial price, terms, and any negotiation positioning: **\[to be
#   determined by underwriting management\]**
# - Ceding commission / brokerage terms: **\[to be determined by underwriting management\]**
# - Competitive and portfolio considerations: **\[to be determined by underwriting management\]**
# - Decision to quote/bind/decline: **\[to be determined by underwriting management\]**
#
# ------------------------------------------------------------------------
#
# ## Peer-Review Checklist Status
#
# Per the Peer-Review Checklist, this draft must be confirmed by a human peer
# reviewer before release. See governed document `peer_review_checklist` for
# the full sign-off list (assumption traceability, section separation,
# sensitivity coverage, reproducibility).
#
# ## Appendix: Full Tool Call Trace (for reproducibility)
#
# **Step 1 — `validate_pricing_submission`**
#
# - Inputs: `({'cedant_name': 'Example Mutual Insurance Co.', 'peril': 'wind', 'current_year': 2027, 'treaty_terms': {'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0}, 'expiring_technical_premium': 7800000, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}},)`
# - Outputs: `{'status': 'PASS_WITH_FLAGS', 'years_supplied': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027], 'n_years': 11, 'issues': ['Missing premium for year 2027.'], 'data_limitation_flag': False}`
#
# **Step 2 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 3 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, {'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'annual_aggregate_limit': 100000000, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37640800.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 4 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37640800.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 5.5869, 2020: 0.0, 2021: 5.6713, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 4.4539, 2026: 0.0}, 'simple_average_burning_cost': 1.5712, 'premium_weighted_average_burning_cost': 1.5765, 'burning_cost_std_dev': 2.4192, 'experience_indication_premium_basis': 13198604.65}`
#
# **Step 5 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.6296, 'severity_lognormal_sigma': 0.1546, 'expected_severity_to_layer': 45880266.67, 'modeled_expected_annual_loss_to_layer': 13764080.0, 'exposure_indication_loss_cost_ratio': 1.644}`
#
# **Step 6 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 7 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 13198604.64603, 'exposure_indication_loss_cost': 13764080.0, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 13511199.42, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1621343.93, 'target_margin_pct': 0.06, 'technical_premium': 18342476.79, 'technical_price_as_pct_of_onlevel_premium': 2.1909}`
#
# **Step 8 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 9 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, {'attachment': 37500000.0, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 37500000.0, 'limit': 50000000, 'reinstatements': 1, 'annual_aggregate_limit': 100000000, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 50000000.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 50000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 10 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 50000000.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 5.5869, 2020: 0.0, 2021: 5.6713, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 5.9163, 2026: 0.0}, 'simple_average_burning_cost': 1.7174, 'premium_weighted_average_burning_cost': 1.7181, 'burning_cost_std_dev': 2.6246, 'experience_indication_premium_basis': 14384093.02}`
#
# **Step 11 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 50000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.7275, 'severity_lognormal_sigma': 0.0, 'expected_severity_to_layer': 50000000.0, 'modeled_expected_annual_loss_to_layer': 15000000.0, 'exposure_indication_loss_cost_ratio': 1.7917}`
#
# **Step 12 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 13 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 14384093.017661998, 'exposure_indication_loss_cost': 15000000.0, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 14724566.4, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1766947.97, 'target_margin_pct': 0.06, 'technical_premium': 19989714.39, 'technical_price_as_pct_of_onlevel_premium': 2.3877}`
#
# **Step 14 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 15 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, {'attachment': 62500000.0, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 62500000.0, 'limit': 50000000, 'reinstatements': 1, 'annual_aggregate_limit': 100000000, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 41100124.84, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 25140800.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 41100124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 25140800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 16 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 41100124.84, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 25140800.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 4.5925, 2020: 0.0, 2021: 5.6713, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 2.9748, 2026: 0.0}, 'simple_average_burning_cost': 1.3239, 'premium_weighted_average_burning_cost': 1.3314, 'burning_cost_std_dev': 2.1114, 'experience_indication_premium_basis': 11146604.65}`
#
# **Step 17 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 41100124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 25140800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.4223, 'severity_lognormal_sigma': 0.3169, 'expected_severity_to_layer': 38746974.95, 'modeled_expected_annual_loss_to_layer': 11624092.48, 'exposure_indication_loss_cost_ratio': 1.3884}`
#
# **Step 18 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 19 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 11146604.646828, 'exposure_indication_loss_cost': 11624092.48, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 11410559.92, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1369267.19, 'target_margin_pct': 0.06, 'technical_premium': 15490699.53, 'technical_price_as_pct_of_onlevel_premium': 1.8503}`
#
# **Step 20 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 21 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, {'attachment': 50000000, 'limit': 37500000.0, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 50000000, 'limit': 37500000.0, 'reinstatements': 1, 'annual_aggregate_limit': 75000000.0, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 37500000.0, 2020: 0.0, 2021: 37500000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37500000.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 37500000.0}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 37500000.0}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37500000.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 22 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 37500000.0, 2020: 0.0, 2021: 37500000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37500000.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 4.1902, 2020: 0.0, 2021: 4.2535, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 4.4372, 2026: 0.0}, 'simple_average_burning_cost': 1.2881, 'premium_weighted_average_burning_cost': 1.2886, 'burning_cost_std_dev': 1.9684, 'experience_indication_premium_basis': 10788279.07}`
#
# **Step 23 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 37500000.0}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 37500000.0}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37500000.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.4399, 'severity_lognormal_sigma': 0.0, 'expected_severity_to_layer': 37500000.0, 'modeled_expected_annual_loss_to_layer': 11250000.0, 'exposure_indication_loss_cost_ratio': 1.3438}`
#
# **Step 24 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 25 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 10788279.065572, 'exposure_indication_loss_cost': 11250000.0, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 11043518.4, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1325222.21, 'target_margin_pct': 0.06, 'technical_premium': 14992412.86, 'technical_price_as_pct_of_onlevel_premium': 1.7908}`
#
# **Step 26 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 27 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, {'attachment': 50000000, 'limit': 62500000.0, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 50000000, 'limit': 62500000.0, 'reinstatements': 1, 'annual_aggregate_limit': 125000000.0, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 53600124.84, 2020: 0.0, 2021: 62500000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37640800.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 53600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 62500000.0}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 28 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 53600124.84, 2020: 0.0, 2021: 62500000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37640800.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 5.9892, 2020: 0.0, 2021: 7.0891, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 4.4539, 2026: 0.0}, 'simple_average_burning_cost': 1.7532, 'premium_weighted_average_burning_cost': 1.7609, 'burning_cost_std_dev': 2.7427, 'experience_indication_premium_basis': 14742418.6}`
#
# **Step 29 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 53600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35, 'loss_to_layer': 62500000.0}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.7228, 'severity_lognormal_sigma': 0.2422, 'expected_severity_to_layer': 51246974.95, 'modeled_expected_annual_loss_to_layer': 15374092.48, 'exposure_indication_loss_cost_ratio': 1.8363}`
#
# **Step 30 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 31 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 14742418.598917998, 'exposure_indication_loss_cost': 15374092.48, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 15091607.92, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1810992.95, 'target_margin_pct': 0.06, 'technical_premium': 20488001.05, 'technical_price_as_pct_of_onlevel_premium': 2.4472}`
#
# **Step 32 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35100614.85}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 101528122.34}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 152916360.3}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18558411.31}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 85887984.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5194000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 33 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35100614.85}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 101528122.34}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 152916360.3}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18558411.31}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 85887984.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5194000.0}]}, {'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'annual_aggregate_limit': 100000000, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 35887984.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35100614.85, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 101528122.34, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 152916360.3, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18558411.31, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 85887984.0, 'loss_to_layer': 35887984.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5194000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 34 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 35887984.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 5.5869, 2020: 0.0, 2021: 5.6713, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 4.2465, 2026: 0.0}, 'simple_average_burning_cost': 1.5505, 'premium_weighted_average_burning_cost': 1.5564, 'burning_cost_std_dev': 2.3952, 'experience_indication_premium_basis': 13030325.58}`
#
# **Step 35 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35100614.85, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 101528122.34, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 152916360.3, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18558411.31, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 85887984.0, 'loss_to_layer': 35887984.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5194000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.6128, 'severity_lognormal_sigma': 0.1784, 'expected_severity_to_layer': 45295994.67, 'modeled_expected_annual_loss_to_layer': 13588798.4, 'exposure_indication_loss_cost_ratio': 1.6231}`
#
# **Step 36 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 37 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 13030325.576328, 'exposure_indication_loss_cost': 13588798.4, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 13339049.35, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1600685.92, 'target_margin_pct': 0.06, 'technical_premium': 18108770.02, 'technical_price_as_pct_of_onlevel_premium': 2.163}`
#
# **Step 38 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 36533293.01}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 105672127.34}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 159157844.4}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 19315897.49}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 89393616.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5406000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 39 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 36533293.01}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 105672127.34}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 159157844.4}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 19315897.49}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 89393616.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5406000.0}]}, {'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'annual_aggregate_limit': 100000000, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 39393616.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 36533293.01, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 105672127.34, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 159157844.4, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 19315897.49, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 89393616.0, 'loss_to_layer': 39393616.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5406000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 40 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 50000000.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 39393616.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 5.5869, 2020: 0.0, 2021: 5.6713, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 4.6613, 2026: 0.0}, 'simple_average_burning_cost': 1.5919, 'premium_weighted_average_burning_cost': 1.5966, 'burning_cost_std_dev': 2.4446, 'experience_indication_premium_basis': 13366883.72}`
#
# **Step 41 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 36533293.01, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 105672127.34, 'loss_to_layer': 50000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 159157844.4, 'loss_to_layer': 50000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 19315897.49, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 89393616.0, 'loss_to_layer': 39393616.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5406000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 3, 'n_years': 10, 'frequency_lambda': 0.3, 'severity_lognormal_mu': 17.6456, 'severity_lognormal_sigma': 0.1312, 'expected_severity_to_layer': 46464538.67, 'modeled_expected_annual_loss_to_layer': 13939361.6, 'exposure_indication_loss_cost_ratio': 1.665}`
#
# **Step 42 — `calculate_credibility_weight`**
#
# - Inputs: `(3,)`
# - Outputs: `{'n_claims_to_layer': 3, 'full_credibility_standard': 15, 'Z': 0.4472, 'note': 'Standard partial credibility formula applied.'}`
#
# **Step 43 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 13366883.715731999, 'exposure_indication_loss_cost': 13939361.6, 'Z': 0.4472, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 13683349.49, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1642001.94, 'target_margin_pct': 0.06, 'technical_premium': 18576183.55, 'technical_price_as_pct_of_onlevel_premium': 2.2188}`
#
# **Step 44 — `trend_and_onlevel_claims`**
#
# - Inputs: `{'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'current_year': 2027, 'peril': 'wind'}`
# - Outputs: `{'peril': 'wind', 'loss_trend_used': 0.06, 'tiv_trend_used': 0.04, 'trended_events_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000, 'trended_amount': 156037102.35}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, 'onlevel_premium_by_year': {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02}}`
#
# **Step 45 — `apply_treaty_structure_to_losses`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84}], 2020: [], 2021: [], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0}]}, {'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0})`
# - Outputs: `{'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'annual_aggregate_limit': 100000000, 'losses_to_layer_by_year': {2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 0.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37640800.0, 2026: 0.0}, 'event_detail_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 50000000}], 2020: [], 2021: [], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}}`
#
# **Step 46 — `calculate_burning_cost`**
#
# - Inputs: `({2017: 0.0, 2018: 0.0, 2019: 50000000.0, 2020: 0.0, 2021: 0.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 37640800.0, 2026: 0.0}, {2017: 8890243.9, 2018: 8894117.65, 2019: 8949438.2, 2020: 8854838.71, 2021: 8816326.53, 2022: 8826923.08, 2023: 8713636.36, 2024: 8538461.54, 2025: 8451219.51, 2026: 8372093.02})`
# - Outputs: `{'years_used': [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], 'annual_burning_cost_ratio': {2017: 0.0, 2018: 0.0, 2019: 5.5869, 2020: 0.0, 2021: 0.0, 2022: 0.0, 2023: 0.0, 2024: 0.0, 2025: 4.4539, 2026: 0.0}, 'simple_average_burning_cost': 1.0041, 'premium_weighted_average_burning_cost': 1.0038, 'burning_cost_std_dev': 2.0241, 'experience_indication_premium_basis': 8403906.97}`
#
# **Step 47 — `fit_frequency_severity_models`**
#
# - Inputs: `({2017: [{'event': 'Hurricane A', 'amount': 20000000, 'trended_amount': 35816953.93, 'loss_to_layer': 0.0}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000, 'trended_amount': 103600124.84, 'loss_to_layer': 50000000}], 2020: [], 2021: [], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000, 'trended_amount': 18937154.4, 'loss_to_layer': 0.0}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000, 'trended_amount': 87640800.0, 'loss_to_layer': 37640800.0}], 2026: [{'event': 'Windstorm F', 'amount': 5000000, 'trended_amount': 5300000.0, 'loss_to_layer': 0.0}]}, 8372093.02)`
# - Outputs: `{'n_claims_to_layer': 2, 'n_years': 10, 'frequency_lambda': 0.2, 'severity_lognormal_mu': 17.5761, 'severity_lognormal_sigma': 0.1975, 'expected_severity_to_layer': 43820400.0, 'modeled_expected_annual_loss_to_layer': 8764080.0, 'exposure_indication_loss_cost_ratio': 1.0468}`
#
# **Step 48 — `calculate_credibility_weight`**
#
# - Inputs: `(2,)`
# - Outputs: `{'n_claims_to_layer': 2, 'full_credibility_standard': 15, 'Z': 0.25, 'note': 'Below minimum claim floor (3); Z capped at 0.25.'}`
#
# **Step 49 — `calculate_technical_price`**
#
# - Inputs: `{'experience_indication_loss_cost': 8403906.973476, 'exposure_indication_loss_cost': 8764080.0, 'Z': 0.25, 'onlevel_premium': 8372093.02}`
# - Outputs: `{'blended_expected_loss_cost': 8674036.74, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1040884.41, 'target_margin_pct': 0.06, 'technical_premium': 11775662.0, 'technical_price_as_pct_of_onlevel_premium': 1.4065}`
#
# **Step 50 — `run_pricing_sensitivities`**
#
# - Inputs: `{'base_case': {'blended_expected_loss_cost': 13511199.42, 'expense_pct': 0.1, 'admin_pct': 0.015, 'capital_load_pct_of_loss_cost': 0.12, 'capital_load_amount': 1621343.93, 'target_margin_pct': 0.06, 'technical_premium': 18342476.79, 'technical_price_as_pct_of_onlevel_premium': 2.1909}, 'submission': {'cedant_name': 'Example Mutual Insurance Co.', 'peril': 'wind', 'current_year': 2027, 'treaty_terms': {'attachment': 50000000, 'limit': 50000000, 'reinstatements': 1, 'reinstatement_cost_pct': 1.0}, 'expiring_technical_premium': 7800000, 'tiv_by_year': {2017: 8200000000, 2018: 8500000000, 2019: 8900000000, 2020: 9300000000, 2021: 9800000000, 2022: 10400000000, 2023: 11000000000, 2024: 11700000000, 2025: 12300000000, 2026: 12900000000, 2027: 13500000000}, 'premium_by_year': {2017: 5400000, 2018: 5600000, 2019: 5900000, 2020: 6100000, 2021: 6400000, 2022: 6800000, 2023: 7100000, 2024: 7400000, 2025: 7700000, 2026: 8000000}, 'losses_by_year': {2017: [{'event': 'Hurricane A', 'amount': 20000000}], 2018: [], 2019: [{'event': 'Windstorm B', 'amount': 65000000}], 2020: [], 2021: [{'event': 'Hurricane C', 'amount': 110000000}], 2022: [], 2023: [{'event': 'Windstorm D', 'amount': 15000000}], 2024: [], 2025: [{'event': 'Hurricane E', 'amount': 78000000}], 2026: [{'event': 'Windstorm F', 'amount': 5000000}]}}, 'pipeline_fn': <bound method TreatyPricingAgent.run_pipeline of <agent.TreatyPricingAgent object at 0x7f765bc34410>>}`
# - Outputs: `{'scenario_technical_premiums': {'base_case': 18342476.79, 'attachment_minus_25pct': 19989714.39, 'attachment_plus_25pct': 15490699.53, 'limit_minus_25pct': 14992412.86, 'limit_plus_25pct': 20488001.05, 'trend_minus_200bps': 18108770.02, 'trend_plus_200bps': 18576183.55, 'largest_loss_removed': 11775662.0}, 'pct_change_vs_base': {'attachment_minus_25pct': 0.0898, 'attachment_plus_25pct': -0.1555, 'limit_minus_25pct': -0.1826, 'limit_plus_25pct': 0.117, 'trend_minus_200bps': -0.0127, 'trend_plus_200bps': 0.0127, 'largest_loss_removed': -0.358}}`
#
# **Step 51 — `compare_to_expiring (internal, non-governed calculation)`**
#
# - Inputs: `{'technical_premium': 18342476.79, 'expiring_technical_premium': 7800000}`
# - Outputs: `{'indicated_rate_change_vs_expiring': 1.3516}`
